# %% [markdown]
# # Introduction
#
# As the trend of on-demand entertainment becoming more prevelant, there is a change in the trend of content creation being less exclusive to a particular network and more avaiable across various content providers. Due to this, there is a competiton across various entertainment provider to provide the right content to the right user to ensure that their users are engaged and reduce their needs to move to another content provider. 1 key factor that can help in pushing the right content to the right users is to have a robust recommendation system.
#
# A singapore start-up which envision to be the Netflix of Singapore, has hired me as a Data scientist to assist their team in creating a recommendation system. They have kindly provided movie rating data from their system. Due to PDPA, no user's profiles are provided.

# %% [markdown]
# ## Problem Statement
# 1. To create a recommendation system based on collaborative filtering to recommend movies to users based on similar movie watched & ratings.
# 2. Recommendation system should provide new contents (w/o rating) users based on user profile to user.

# %% [markdown]
# ## Import Library

# %%
import numpy as np
import pandas as pd
import glob

import matplotlib.pyplot as plt
import seaborn as sns

# API Call
import requests

# %% [markdown]
# ## Import Data sets

# %% [markdown]
# ### Importing of Movie title file

# %%
# Import Movie titles file
titles = pd.read_csv('datasets/movie_titles.txt', sep = ',', names=['movie_id','year_of_release','title'], encoding='Latin_1')

# %%
# convert all movie title to lower case
titles['title'] = titles['title'].map(lambda x: str.lower(x))

# %%
print(f'shape of titles {titles.shape}')
titles.head()
# Out:
# shape of titles (17770, 3)

# %%
# For testing purpose
test = titles.head(1_000)
test.head()
# Out:
#    movie_id  year_of_release                         title
# 0         1           2003.0               dinosaur planet
# 1         2           2004.0    isle of man tt 2004 review
# 2         3           1997.0                     character
# 3         4           1994.0  paula abdul's get up & dance
# 4         5           2004.0      the rise and fall of ecw

# %% [markdown]
# ### Connect to TheMoiveDB.org

# %%
# API key
REQUEST_TOKEN = 'd8f46f139abc47c1f048f3efc486fe53'

# Target web page:

# To authenticate api call session
url = "https://www.themoviedb.org/authenticate/"+ REQUEST_TOKEN

# Establishing the connection to the web page:
response = requests.get(url)

# You can use status codes to understand how the target server responds to your request.
# Ex., 200 = OK, 400 = Bad Request, 403 = Forbidden, 404 = Not Found.
print(response.status_code)
# Out:
# 200

# %%
# Create a function for API call for different movie titles

def title_pull(item_name, item_release_year):
    
    global REQUEST_TOKEN
    
    # replace whitespace with %20
    item = item_name.replace(" ", "%20")

    print(f'currently working on {item_name}')
    
    # Try to search based on movie
    try:
        # Set URL for 1st page result
        url = f"https://api.themoviedb.org/3/search/movie?api_key={REQUEST_TOKEN}&query={item}&primary_release_year={item_release_year}&page=1"
        req = requests.get(url)
        # convert request into json file
        sq_dict = req.json()
        result = sq_dict['results'][0]
        # return the 1st item of the result dict from the sq_dict
        return result
    
    except:
        pass
    
    # Try to search based on TV
    try:
        # Set URL for 1st page result
        url = f"https://api.themoviedb.org/3/search/tv?api_key={REQUEST_TOKEN}&query={item}&first_air_date_year={item_release_year}&page=1"
        req = requests.get(url)
        # convert request into json file
        sq_dict = req.json()
        result = sq_dict['results'][0]
        # return the 1st item of the result dict from the sq_dict
        return result
    
    except:
        # Return 'NA' if not able to search title
        return "NA"

# %%
# %%time

# Create a column of pulled result based on title & release_year
test['moviedb_result'] = test.apply(lambda x: title_pull(x['title'], x['year_of_release']),axis=1)
# Out:
# currently working on dinosaur planet
# currently working on isle of man tt 2004 review
# currently working on character
# currently working on paula abdul's get up & dance
# currently working on the rise and fall of ecw
# currently working on sick
# currently working on 8 man
# currently working on what the #$*! do we know!?
# currently working on class of nuke 'em high 2
# currently working on fighter
# currently working on full frame: documentary shorts
# currently working on my favorite brunette
# currently working on lord of the rings: the return of the king: extended edition: bonus material
# currently working on nature: antarctica
# currently working on neil diamond: greatest hits live
# currently working on screamers
# currently working on 7 seconds
# currently working on immortal beloved
# currently working on by dawn's early light
# currently working on seeta aur geeta
# currently working on strange relations
# currently working on chump change
# currently working on clifford: clifford saves the day! / clifford's fluffiest friend cleo
# currently working on my bloody valentine
# currently working on inspector morse 31: death is now my neighbour
# currently working on never die alone
# currently working on sesame street: elmo's world: the street we live on
# currently working on lilo and stitch
# currently working on boycott
# currently working on something's gotta give
# currently working on classic albums: meat loaf: bat out of hell
# currently working on abc primetime: mel gibson's the passion of the christ
# currently working on aqua teen hunger force: vol. 1
# currently working on ashtanga yoga: beginner's practice with nicki doane
# currently working on ferngully 2: the magical rescue
# currently working on lady chatterley
# currently working on zatoichi's conspiracy
# currently working on daydream obsession
# currently working on love reinvented
# currently working on pitcher and the pin-up
# currently working on horror vision
# currently working on searching for paradise
# currently working on silent service
# currently working on spitfire grill
# currently working on the love letter
# currently working on rudolph the red-nosed reindeer
# currently working on the bad and the beautiful
# currently working on justice league
# currently working on devo: the complete truth about de-evolution
# currently working on a yank in the r.a.f.
# currently working on jonah: a veggietales movie: bonus material
# currently working on the weather underground
# currently working on the bonesetter
# currently working on we're not married
# currently working on jade
# currently working on carandiru
# currently working on richard iii
# currently working on dragonheart
# currently working on sex and the beauties
# currently working on the libertine
# currently working on ricky martin: one night only
# currently working on ken burns' america: empire of the air
# currently working on crash dive
# currently working on outside the law
# currently working on lost in the pershing point hotel
# currently working on barbarian queen 2
# currently working on vampire journals
# currently working on invader zim
# currently working on wwe: armageddon 2003
# currently working on tai chi: the 24 forms
# currently working on maya lin: a strong clear vision
# currently working on at home among strangers
# currently working on davy crockett: 50th anniversary double feature
# currently working on 6ixtynin9
# currently working on grind
# currently working on i love lucy: season 2
# currently working on congo
# currently working on jingle all the way
# currently working on the killing
# currently working on winter kills
# currently working on antarctica: imax
# currently working on the frogmen
# currently working on silkwood
# currently working on the powerpuff girls movie
# currently working on elfen lied
# currently working on iron monkey 2
# currently working on louder than bombs
# currently working on record of lodoss war: chronicles of the heroic knight
# currently working on chain of command
# currently working on the lemon drop kid
# currently working on wwe: royal rumble 2005
# currently working on ecw: cyberslam '99
# currently working on they came back
# currently working on g3: live in concert
# currently working on dona herlinda and her son
# currently working on inside the space station
# currently working on mostly martha
# currently working on the battle of algiers: bonus material
# currently working on a fishy story
# currently working on sam the iron bridge
# currently working on complete shamanic princess
# currently working on notre musique
# currently working on sanford and son: season 6
# currently working on the great race
# currently working on obsessed
# currently working on stevie ray vaughan and double trouble: live at montreux 1982 & 1985
# currently working on magnolia: bonus material
# currently working on spartan
# currently working on no way back
# currently working on scandal
# currently working on duplex (widescreen)
# currently working on the eye of vichy
# currently working on bruce lee: a warrior's journey
# currently working on dominion tank police part 1 & 2
# currently working on lord peter wimsey: murder must advertise
# currently working on bear cub
# currently working on silk stockings
# currently working on rambo: first blood part ii
# currently working on travel the world by train: africa
# currently working on plain dirty
# currently working on beyonce: live at wembley
# currently working on cube 2: hypercube
# currently working on chain of fools
# currently working on cold blooded
# currently working on nighthawks
# currently working on vampire effect (aka twins effect)
# currently working on fatal beauty
# currently working on mr. vampire
# currently working on darkwolf
# currently working on drowning on dry land
# currently working on arachnid
# currently working on lucio fulci: the beyond
# currently working on viva la bam: season 1
# currently working on spirit lost
# currently working on gto: great teacher onizuka: set 2
# currently working on cat and the canary
# currently working on naked lies
# currently working on star trek: voyager: season 1
# currently working on allergies: a natural approach
# currently working on lost in the wild
# currently working on goddess of mercy
# currently working on the tricky master
# currently working on the game
# currently working on deepak chopra: the way of the wizard & alchemy
# currently working on get out your handkerchiefs
# currently working on cannibal women in the avocado jungle of death
# currently working on where sleeping dogs lie
# currently working on sweet november
# currently working on the edward r. murrow collection
# currently working on firetrap
# currently working on sleepover nightmare
# currently working on a little princess
# currently working on mtv yoga
# currently working on demon warrior koji
# currently working on the strongest man in the world
# currently working on husbands and wives
# currently working on laird: white knuckle extreme
# currently working on a killer within
# currently working on gentlemen of fortune
# currently working on gormenghast
# currently working on ninotchka
# currently working on john cleese on how to irritate people
# currently working on mtv: making the band 2: best of season 1
# currently working on one last dance
# currently working on richard pryor: live on the sunset strip
# currently working on fame
# currently working on the chorus
# currently working on smokey and the bandit part 3
# currently working on cartoon network halloween: 9 creepy cartoon capers
# currently working on tomorrow
# currently working on funny face
# currently working on jack
# currently working on the devil's brigade
# currently working on adam-12: season 1
# currently working on reservoir dogs
# currently working on the history channel presents: troy: unearthing the legend
# currently working on pressure
# currently working on regular guys
# currently working on bollywood bound
# currently working on scratch
# currently working on the last shot
# currently working on moby: play
# currently working on ifilm: deranged
# currently working on billy blanks: tae bo: cardio circuit 1
# currently working on missing in action 2: the beginning / missing in action 3: braddock
# currently working on panic in the streets
# currently working on death to smoochy
# currently working on dead birds
# currently working on airplane ii: the sequel
# currently working on blood and sand
# currently working on x2: x-men united
# currently working on the soultaker
# currently working on marilyn manson: fear of a satanic planet
# currently working on arliss: the best of arliss
# currently working on chasing freedom
# currently working on peter tosh: stepping razor: red x
# currently working on taking lives
# currently working on gupt
# currently working on the deer hunter
# currently working on the fall of the roman empire
# currently working on home movie
# currently working on ruby's bucket of blood
# currently working on sports illustrated swimsuit edition: 1997
# currently working on venus boyz
# currently working on troy: bonus material
# currently working on unconstitutional: the war on our civil liberties
# currently working on denise austin: ultimate fat burner
# currently working on the three stooges: sing a song of six pants
# currently working on star trek: deep space nine: season 5
# currently working on onmyoji
# currently working on the agronomist
# currently working on querelle
# currently working on dinner rush
# currently working on read-along: beauty and the beast
# currently working on that '70s show: season 1
# currently working on impostor
# currently working on cherry 2000
# currently working on triumph: live at the us festival
# currently working on neon bible
# currently working on winston churchill: the wilderness years
# currently working on voyage to the planets and beyond
# currently working on yellow
# currently working on chappelle's show: season 1
# currently working on midsomer murders: blood will out
# currently working on the cookout
# currently working on henry: portrait of a serial killer 2
# currently working on the carol burnett show: show stoppers
# currently working on butch and sundance: the early days
# currently working on peter gabriel: growing up live
# currently working on unsolved mysteries: psychics
# currently working on marooned in iraq
# currently working on gross anatomy
# currently working on chato's land
# currently working on animation legend: winsor mccay
# currently working on unhook the stars
# currently working on cartoon crazys sci-fi
# currently working on broken blossoms
# currently working on led zeppelin: the song remains the same
# currently working on winnie the pooh: springtime with roo
# currently working on woman of the year
# currently working on north by northwest
# currently working on neon genesis evangelion: the end of evangelion
# currently working on pressure point
# currently working on stellvia
# currently working on road dogz
# currently working on the boston strangler
# currently working on oleanna
# currently working on michael moore's the awful truth: season 2
# currently working on the hunters
# currently working on cast a giant shadow
# currently working on midsomer murders: strangler's wood
# currently working on stuart little 2
# currently working on a night at the opera
# currently working on westender
# currently working on the hunchback of notre dame ii
# currently working on ghost dog: the way of the samurai
# currently working on charlotte's web
# currently working on mann
# currently working on animal
# currently working on marat / sade
# currently working on the big clock
# currently working on herbie rides again
# currently working on dragon ball: tournament saga
# currently working on angelina ballerina: lights
# currently working on the jeff corwin experience: costa rica and the amazon
# currently working on saudade do futuro
# currently working on touched by an angel: season 1
# currently working on the final countdown
# currently working on parenthood
# currently working on sex and the city: season 4
# currently working on saludos amigos
# currently working on female yakuza tale
# currently working on taxi
# currently working on crazy as hell
# currently working on evelyn
# currently working on cold harvest
# currently working on enigma: mcmxc a.d
# currently working on 100 days before the command
# currently working on micki and maude
# currently working on sarah brightman: in concert
# currently working on the legend
# currently working on blue seed: beyond
# currently working on if these walls could talk
# currently working on sasquatch hunters
# currently working on the devil's own
# currently working on thunderbirds are go
# currently working on luther vandross: always and forever: an evening of songs
# currently working on saturday night live: the best of chris kattan
# currently working on the avengers
# currently working on harold and kumar go to white castle
# currently working on chained heat 3: hell mountain
# currently working on saturday night live: the best of gilda radner
# currently working on lennon legend: the very best of john lennon
# currently working on oasis
# currently working on ace ventura: when nature calls
# currently working on in his life: the john lennon story
# currently working on the hebrew hammer
# currently working on crunch: pick your spot pilates
# currently working on bridget jones's diary
# currently working on option zero
# currently working on hard ground
# currently working on the isle
# currently working on les liaisons dangereuses
# currently working on king of the hill: season 1
# currently working on jack
# currently working on sesame street: sing yourself silly!
# currently working on godsmack: smack this!
# currently working on the legend of the 7 golden vampires/7 brothers of dracula
# currently working on the day of the locust
# currently working on leila
# currently working on ed wood
# currently working on high fidelity
# currently working on pay it forward
# currently working on saturday night live: the best of jon lovitz
# currently working on combat! season 3: operation 2
# currently working on futurama: monster robot maniac fun collection
# currently working on mandela and de klerk
# currently working on beyond suspicion
# currently working on straight to hell
# currently working on eat your heart out
# currently working on ju-rei: the uncanny
# currently working on flesh gordon
# currently working on modern vampires
# currently working on mother's boys
# currently working on ghosts of rwanda: frontline
# currently working on the plainsman
# currently working on storefront hitchcock
# currently working on deftones: live in hawaii
# currently working on dogma
# currently working on wild things
# currently working on chasing amy
# currently working on they crawl
# currently working on mail call: the best of season 2
# currently working on the pacifier
# currently working on fear no evil
# currently working on the driver
# currently working on star 80
# currently working on the three stooges: three smart saps
# currently working on rolling stones: rock and roll circus
# currently working on midnight: 2000 seen by...
# currently working on tremors 4: the legend begins
# currently working on noir
# currently working on french and saunders: live
# currently working on the taming of the shrew
# currently working on star trek: voyager: season 5
# currently working on up and down
# currently working on iceman cometh
# currently working on the last temptation of christ
# currently working on the swarm
# currently working on dr. quinn
# currently working on guns of the magnificent seven
# currently working on pick a card
# currently working on life or something like it
# currently working on sadomania
# currently working on sinful nuns of st. valentine
# currently working on look at me
# currently working on house of sand and fog
# currently working on the onion field
# currently working on absolutely fabulous: series 5
# currently working on lies
# currently working on the phantom of the opera: special edition
# currently working on the flintstones in viva rock vegas
# currently working on stark raving mad
# currently working on billy blanks: tae bo: contact 2
# currently working on r.e.m.: tourfilm
# currently working on still
# currently working on spun
# currently working on the best of designing women
# currently working on playing mona lisa
# currently working on chaplin
# currently working on the trouble with angels
# currently working on jeans
# currently working on third world cop
# currently working on the little girl who lives down the lane
# currently working on nine dead gay guys
# currently working on genesis: the way we walk: live in concert
# currently working on dick francis: the racing game
# currently working on party monster
# currently working on crash dive
# currently working on live wire
# currently working on out for justice
# currently working on buried in the sand: the deception of america
# currently working on hit team
# currently working on crossroads
# currently working on the santa clause 2
# currently working on princess caraboo
# currently working on bizet's carmen
# currently working on body chemistry
# currently working on steal
# currently working on the fan
# currently working on the monkees: season 2
# currently working on danielle steel's heartbeat
# currently working on the replacement killers
# currently working on 20
# currently working on captain blood
# currently working on arjuna: complete collection
# currently working on a night in casablanca
# currently working on in the realm of the senses
# currently working on fangs
# currently working on rio lobo
# currently working on halloween 5: the revenge of michael myers
# currently working on pan tadeusz
# currently working on substitute 4: failure is not an option
# currently working on the shaft
# currently working on wings of desire
# currently working on hostage
# currently working on the abductors
# currently working on nightbreed
# currently working on godzilla vs. the sea monster
# currently working on frank lloyd wright
# currently working on vendetta
# currently working on jay jay the jet plane: adventures in learning
# currently working on igby goes down
# currently working on girl
# currently working on reign in darkness
# currently working on elephant
# currently working on transformers: season 3: part 1
# currently working on the deal
# currently working on george lopez: why you crying?
# currently working on saturday night live: the best of dana carvey
# currently working on agatha christie's poirot: sad cypress
# currently working on the unsinkable molly brown
# currently working on my favorite martian #1
# currently working on happiness
# currently working on the 10th kingdom
# currently working on recess: school's out
# currently working on graveyard shift
# currently working on barney: barney's colorful world: live
# currently working on zeus and roxanne
# currently working on chobits
# currently working on millennium actress
# currently working on les miserables in concert
# currently working on untamed heart
# currently working on extreme engineering: tokyo's sky city
# currently working on love can seriously damage your health
# currently working on girls just want to have fun
# currently working on beyblade: fierce battle
# currently working on bean: the movie
# currently working on town without pity
# currently working on just 4 kicks
# currently working on dark shadows: vol. 9
# currently working on mississippi burning
# currently working on rabbit-proof fence
# currently working on the inner tour
# currently working on michael collins
# currently working on the underneath
# currently working on the making of fanny and alexander
# currently working on oswald: welcome to the big city!
# currently working on jimmy buffett: minimatinee #1
# currently working on isaac stern: life's virtuoso
# currently working on batman the animated series: vol. 3
# currently working on scorched
# currently working on simple men
# currently working on xena: warrior princess: season 3
# currently working on cardcaptor sakura: the movie
# currently working on emma (miniseries)
# currently working on kill bill: vol. 2
# currently working on blast
# currently working on basquiat
# currently working on pink narcissus
# currently working on nightwalker #1: midnight detective
# currently working on classic cartoon favorites: starring donald
# currently working on the twilight zone: vol. 12
# currently working on the return of ruben blades
# currently working on coolie no.1
# currently working on doogie howser
# currently working on topper returns
# currently working on the matrix: revolutions
# currently working on first night of my life: 2000 seen by...
# currently working on beneath loch ness
# currently working on city lights
# currently working on mr. jealousy
# currently working on princess mononoke
# currently working on legend of 1900
# currently working on surf ninjas
# currently working on veggietales classics: where's god when i'm scared?
# currently working on george carlin: personal favorites
# currently working on the beverly hillbillies
# currently working on george carlin: what am i doing in new jersey?
# currently working on flypaper
# currently working on building the great pyramid
# currently working on frida
# currently working on rush hour 2
# currently working on danielle steel's jewels
# currently working on the avengers '67
# currently working on journey to the center of the earth
# currently working on doctor who: lost in time: the patrick troughton years
# currently working on his secret life
# currently working on return to paradise
# currently working on the passion of ayn rand
# currently working on torn curtain
# currently working on mrs. soffel
# currently working on the giallo collection: who saw her die?
# currently working on monty python's the meaning of life: special edition
# currently working on mission kashmir
# currently working on primus: hallucino-genetics live 2004
# currently working on broadway's lost treasures
# currently working on glory: bonus material
# currently working on under suspicion
# currently working on mail call: the best of season 1
# currently working on three days of the condor
# currently working on mitch hedberg: mitch all together
# currently working on max and ruby: springtime for max and ruby
# currently working on the twilight zone: vol. 27
# currently working on a thousand acres
# currently working on blank generation / dancin' barefoot
# currently working on nevada smith
# currently working on saint jack
# currently working on the volcano disaster
# currently working on blue's clues: blue's room: it's hug day
# currently working on avenging angelo
# currently working on bubblegum crisis: hurricane live!
# currently working on butterfly kiss
# currently working on santana: supernatural live
# currently working on avia vampire hunter
# currently working on monsoon wedding
# currently working on two can play that game
# currently working on the prime of miss jean brodie
# currently working on from mao to mozart: isaac stern in china
# currently working on e's otherwise
# currently working on presenting felix the cat
# currently working on love songs
# currently working on my side of the mountain
# currently working on mumford
# currently working on the last seduction ii
# currently working on angie
# currently working on barbarian queen
# currently working on the hitchhiker's guide to the galaxy
# currently working on summer of the monkeys
# currently working on return to horror high
# currently working on you're invited to mary-kate and ashley's vacation parties
# currently working on young einstein
# currently working on drop dead fred
# currently working on with a friend like harry
# currently working on the alamo
# currently working on sol goode
# currently working on here is greenwood
# currently working on a crime of passion
# currently working on rumpole of the bailey: series 4
# currently working on ghosts of the abyss: bonus material
# currently working on king cobra
# currently working on the blackout
# currently working on roughnecks: the starship troopers chronicles: the pluto campaign
# currently working on maurice: bonus material
# currently working on bob the builder: the big game
# currently working on the strip game
# currently working on kuffs
# currently working on hudson hawk
# currently working on rage at dawn
# currently working on first knight
# currently working on the santa clause
# currently working on radioland murders
# currently working on rangeela
# currently working on solaris
# currently working on cadfael: a morbid taste for bones
# currently working on new waterford girl
# currently working on liebestraum
# currently working on fantastic four
# currently working on rebecca: bonus material
# currently working on star trek: enterprise: season 3
# currently working on high and low
# currently working on bloody mallory
# currently working on jimmy neutron: boy genius
# currently working on predator 2
# currently working on tom petty and the heartbreakers: live at the olympic: the last dj
# currently working on bullet
# currently working on dunsmore
# currently working on knights of ramune
# currently working on the in-laws
# currently working on the visit
# currently working on american beauty
# currently working on the masque of the red death / the premature burial
# currently working on winners & sinners
# currently working on strangers when we meet
# currently working on highlander: season 4
# currently working on popular: season 2
# currently working on the twilight zone: vol. 36
# currently working on the terror
# currently working on the autobiography of miss jane pittman
# currently working on thx 1138: special edition
# currently working on black jack: the movie
# currently working on jo jo dancer
# currently working on third man on the mountain
# currently working on the curve
# currently working on my family
# currently working on shanghai triad
# currently working on the scarlet and the black
# currently working on blue planet: imax
# currently working on northanger abbey
# currently working on michael mcdonald: a gathering of friends
# currently working on particles of truth
# currently working on house of whipcord
# currently working on baby genius: mozart and friends
# currently working on by hook or by crook
# currently working on monarch of the glen: series 2
# currently working on alice in wonderland (tv version)
# currently working on the brady bunch variety hour
# currently working on bobby darin: mack is back
# currently working on sea of love
# currently working on what's up
# currently working on the smiths: the complete picture
# currently working on tokyo raiders
# currently working on burn up excess: vol. 1: to serve and protect
# currently working on walt disney's timeless tales: vol. 2
# currently working on the secrets of the dead sea scrolls
# currently working on quatermass and the pit
# currently working on speed
# currently working on the lickerish quartet
# currently working on jimmy neutron: attack of the twonkies
# currently working on offspring: americana
# currently working on spooks & creeps
# currently working on cloak and dagger
# currently working on the dr. who collection
# currently working on bad boy bubby
# currently working on an ideal husband
# currently working on sctv network 90: vol. 4
# currently working on ufc: ultimate fighting championship: ultimate knockouts 3
# currently working on totally f***ed up
# currently working on doctor who: the leisure hive
# currently working on hot wheels: world race
# currently working on armageddon
# currently working on talkin' dirty after dark
# currently working on dario argento collection: vol. 2: demons 2
# currently working on my mother likes women
# currently working on underground comedy movie
# currently working on they died with their boots on
# currently working on beware of a holy whore
# currently working on rescue heroes: the movie
# currently working on firestarter
# currently working on empire of the ants
# currently working on unleashed
# currently working on shaft's big score!
# currently working on baazigar
# currently working on christmas with the simpsons
# currently working on the fassbinder collection: pioneer in ingolstadt
# currently working on stir crazy
# currently working on national geographic: inside american power: air force one
# currently working on the last dragon
# currently working on jim brown: all-american
# currently working on to catch a killer
# currently working on charly
# currently working on mystery science theater 3000: the hellcats
# currently working on buying the cow
# currently working on cheyenne warrior
# currently working on dear frankie
# currently working on matewan
# currently working on cinderfella
# currently working on john mayall & the bluesbreakers and friends: 70th birthday concert
# currently working on ricky martin: the ricky martin video collection
# currently working on elvira's haunted hills
# currently working on the rainbow fish / dazzle the dinosaur
# currently working on marvin's room
# currently working on american tragedy
# currently working on return of the chinese boxer
# currently working on green acres: season 1
# currently working on veronica 2030
# currently working on highlander: season 5
# currently working on robin hood: prince of thieves
# currently working on the last house on the left
# currently working on saving grace
# currently working on who is cletis tout?
# currently working on rob roy
# currently working on la femme nikita: season 3
# currently working on office killer
# currently working on lipstick
# currently working on the man who came to dinner
# currently working on gilligan's island: season 2
# currently working on saturday night live: the best of will ferrell 2
# currently working on real kung fu of shaolin
# currently working on he loves me
# currently working on the winter people
# currently working on he said
# currently working on fight club: bonus material
# currently working on hellbound: hellraiser ii
# currently working on rugrats all grown up: o' brother!
# currently working on mafia!
# currently working on in the mood for love
# currently working on loves of a blonde
# currently working on r.e.m.: pop screen
# currently working on better than sex
# currently working on police academy 3: back in training
# currently working on the mighty
# currently working on cavalry charge
# currently working on visitors of the night
# currently working on running out of time
# currently working on bedazzled
# currently working on peter jennings reports: the kennedy assassination: beyond conspiracy
# currently working on the history channel presents: the alamo
# currently working on one true thing
# currently working on baby einstein: baby da vinci
# currently working on angel's dance
# currently working on the hand that rocks the cradle
# currently working on the quest
# currently working on when dinosaurs roamed america
# currently working on koma
# currently working on last man standing
# currently working on caillou: caillou's treasure hunt and other adventures
# currently working on daud
# currently working on mahoromatic: automatic maiden: summer special
# currently working on todd mcfarlane's spawn
# currently working on nine lives
# currently working on for the moment
# currently working on japan: memoirs of a secret empire
# currently working on a change of heart
# currently working on major league
# currently working on mobsters
# currently working on the return
# currently working on the perfect storm
# currently working on africans in america: america's journey through slavery
# currently working on inspector morse 9: the last enemy
# currently working on dolores claiborne
# currently working on homicide: life on the street: season 7
# currently working on cause celebre
# currently working on whisper kill
# currently working on film noir collection: d.o.a.
# currently working on the bravados
# currently working on testosterone
# currently working on 44 minutes
# currently working on city of industry
# currently working on roger & me
# currently working on royal deceit
# currently working on the wire: season 1
# currently working on curly sue
# currently working on yu yu hakusho
# currently working on woman thou art loosed
# currently working on the haunting of morella
# currently working on carlton-browne of the f.o.
# currently working on abigail's party
# currently working on fast food
# currently working on bagdad cafe
# currently working on mr. magoo
# currently working on 11:14
# currently working on dead ringers
# currently working on indochine
# currently working on hillary & tenzing: climbing to the roof of world
# currently working on the last man
# currently working on great pas de deux
# currently working on a slipping down life
# currently working on treading water
# currently working on the house on carroll street
# currently working on ken burns' america: the congress
# currently working on sherlock: case of evil
# currently working on widows' peak
# currently working on hot war
# currently working on fantasy mission force
# currently working on domestic disturbance
# currently working on saber marionette j
# currently working on i can do bad all by myself
# currently working on ernest goes to jail
# currently working on the librarian: quest for the spear
# currently working on halloween: h2o
# currently working on star trek: the next generation: season 7
# currently working on mary poppins: bonus material
# currently working on the lonely guy
# currently working on music box
# currently working on the best of musikladen: classic rock
# currently working on sherlock hound
# currently working on mean girls
# currently working on fifteen minutes
# currently working on pooh's heffalump movie
# currently working on o fantasma
# currently working on end of the century: the story of the ramones
# currently working on the poseidon adventure
# currently working on scarface: 20th anniversary edition: bonus material
# currently working on grief
# currently working on a hole in the head
# currently working on edges of the lord
# currently working on the star maker
# currently working on the crawling eye
# currently working on a perfect candidate
# currently working on man in the iron mask
# currently working on gloria estefan: don't stop!
# currently working on he died with a felafel in his hand
# currently working on foyle's war: set 2
# currently working on man ray: prophet of the avant garde
# currently working on dr. seuss's the 5
# currently working on sherlock holmes and the spider woman
# currently working on a touch of frost: seasons 7 & 8
# currently working on loving jezebel
# currently working on churchill
# currently working on care bears: journey to joke-a-lot
# currently working on soldier of fortune
# currently working on for love or country
# currently working on the outer limits: the new series: aliens among us
# currently working on american pop
# currently working on tokyo drifter
# currently working on la vallee
# currently working on clerks
# currently working on boyz n the hood
# currently working on a single girl
# currently working on don henley: live inside job
# currently working on unsolved history: salem witch trials
# currently working on by brakhage: an anthology
# currently working on a stranger among us
# currently working on landmarks of early film
# currently working on rabid
# currently working on look back in anger
# currently working on jaws
# currently working on teen titans: season 1
# currently working on dracula vs. frankenstein
# currently working on we know where you live. live!
# currently working on spies
# currently working on soul assassin
# currently working on sherlock holmes: the scarlet claw
# currently working on dark shadows: vol. 11
# currently working on eyes without a face
# currently working on the mouse that roared
# currently working on dead man on campus
# currently working on left behind ii: tribulation force
# currently working on the matchmaker
# currently working on the lawnmower man
# currently working on the saddle club: horse crazy
# currently working on on cukor
# currently working on ruin explorers
# currently working on tiger bay
# currently working on marlene dietrich: her own song
# currently working on my bodyguard
# currently working on logan's run
# currently working on the faculty
# currently working on predator island
# currently working on slaughter
# currently working on star trek: enterprise: season 1
# currently working on sleepaway camp ii: unhappy campers
# currently working on a piece of the action
# currently working on bill cosby: himself
# currently working on goosebumps: cry of the cat
# currently working on c'est la vie
# currently working on atlantis
# currently working on serial mom
# currently working on return to a better tomorrow
# currently working on mannequin
# currently working on tupac: resurrection
# currently working on white squall
# currently working on niagara: miracles
# currently working on cirque du soleil: a baroque odyssey
# currently working on incident at oglala: the leonard peltier story
# currently working on all in the family: season 3
# currently working on gang of roses
# currently working on the thin man goes home
# currently working on the lady eve
# currently working on there goes my baby
# currently working on reap the wild wind
# currently working on mansfield park
# currently working on la cienaga
# currently working on if we had no moon
# currently working on enduring love
# currently working on shania twain: the platinum collection
# currently working on la separation
# currently working on mr. & mrs. bridge
# currently working on stoked: the rise and fall of gator
# currently working on back to the future part iii
# currently working on disorganized crime
# currently working on dragonball: the magic begins
# currently working on wes craven's invitation to hell
# currently working on bruiser
# currently working on devil in the flesh 2
# currently working on the three stooges go around the world in a daze
# currently working on sports illustrated swimsuit edition: 2002
# currently working on creepshow
# currently working on crime partners
# currently working on rush: rush in rio
# currently working on tuck everlasting
# currently working on king of new york: special edition (full-screen)
# currently working on laughing out loud: vol. 1
# currently working on elvis by the presleys
# currently working on starsky & hutch: season 1
# currently working on my dream girl
# currently working on la promesse
# currently working on without limits: nasa test projects
# currently working on h.g. wells and the war of the worlds: a documentary
# currently working on the jewel in the crown
# currently working on seven samurai
# currently working on boys life 4: four play
# currently working on elvis costello & the imposters: live in memphis
# currently working on zakhm
# currently working on super gals
# currently working on a love divided
# currently working on short: international release #2
# currently working on mikey and nicky
# currently working on sharpe 4: sharpe's enemy
# currently working on mating habits of the earthbound human
# currently working on gloria estefan: evolution tour: live in miami
# currently working on deep cover
# currently working on cup final
# currently working on the maldonado miracle
# currently working on ray
# currently working on monster-in-law: bonus material
# currently working on discovering australia
# currently working on reno 911: season 2
# currently working on harsh realm: the complete series
# currently working on zakk wylde's black label society: boozed
# currently working on the bedford incident
# currently working on blue's clues: classic clues
# currently working on the muse
# currently working on dersu uzala
# currently working on dangerous minds
# currently working on bride and prejudice
# currently working on the body
# currently working on out of ireland: the hit songs and artists of irish music
# currently working on eat drink man woman
# currently working on diary of a country priest
# currently working on fascination
# currently working on hamlet
# currently working on gargoyles
# currently working on remedy
# currently working on benny hill: complete and unadulterated: the naughty early years: set 1
# currently working on animal crackers
# currently working on sense and sensibility
# currently working on too young to die
# currently working on santa fe trail
# currently working on buck rogers
# currently working on angelina ballerina: friends forever
# currently working on dead kennedys: in god we trust
# currently working on r.e.m.: road movie
# currently working on haven
# currently working on earth 2: the complete series
# currently working on string cheese incident: live at the fillmore
# currently working on a hard day's night: collector's series
# currently working on comedian
# currently working on satanis: the devil's mass / sinthia: the devil's doll: double feature
# currently working on don't bother to knock
# currently working on gojoe: spirit war chronicle
# currently working on giant robo
# currently working on taxi zum klo
# currently working on dodsworth
# currently working on fear of a punk planet
# currently working on danielle steel's changes
# currently working on the night that never happened
# currently working on journeys with george
# currently working on back to the beach
# currently working on another day in paradise
# currently working on where are we?
# currently working on backyardigans: it's great to be a ghost
# currently working on river of no return
# currently working on read or die
# currently working on a dangerous man: lawrence after arabia
# currently working on fallen
# currently working on scarecrow
# currently working on midsomer murders: a tale of two hamlets
# currently working on hercules
# currently working on screw loose
# currently working on the pagemaster
# currently working on dave chappelle: for what it's worth
# currently working on brother
# currently working on the duel at silver creek
# currently working on sex and the teenage mind
# currently working on the cincinnati kid
# currently working on aap mujhe achche lagne lage
# currently working on henry fool
# currently working on explosive dance
# currently working on richard rodgers: the sweetest sounds
# currently working on my favorite wife
# currently working on fahrenheit 451
# currently working on i capture the castle
# currently working on rhyme & reason
# currently working on blankman
# currently working on lost in space: season 2: vol. 1
# currently working on world cup soccer highlights: 1966-1974
# currently working on jay jay the jet plane: lessons for all seasons
# currently working on the unforgiven
# currently working on love in the afternoon
# currently working on i spy
# currently working on a streetcar named desire
# currently working on the tick: the entire series
# currently working on metropolitan opera: puccini: tosca
# currently working on young and dangerous 2
# currently working on main hoon na
# currently working on dottie gets spanked
# currently working on stripteaser
# currently working on yesterday once more
# currently working on unprecedented: the 2000 presidential election
# currently working on ben harper: live at the hollywood bowl
# currently working on dr. martin luther king
# currently working on the devil and daniel webster
# currently working on convict 762
# currently working on tom and jerry: paws for a holiday
# currently working on our lady of the assassins
# currently working on yi yi
# currently working on a moment of romance
# currently working on the swan princess
# currently working on how i got into college
# currently working on dil chahta hai
# currently working on wishful thinking
# currently working on the young lions
# currently working on the mummy
# currently working on the trip
# currently working on rescue from gilligan's island
# currently working on operation pacific
# currently working on the door in the floor
# currently working on meet john doe
# currently working on burn up excess: vol. 2: crimes and missed demeanors
# currently working on the cowboys
# currently working on the shadow
# currently working on children of the corn
# currently working on dark town
# currently working on yojimbo
# currently working on miracle of the white stallions
# currently working on frida: bonus material
# currently working on the favor
# currently working on jim breuer: hardcore
# Wall time: 7min 12s
# <timed exec>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test[test['moviedb_result']=='NA']
# Out:
#      movie_id  year_of_release  \
# 1           2           2004.0
# 10         11           1999.0
# 12         13           2003.0
# 13         14           1982.0
# 15         16           1996.0
# ..        ...              ...
# 964       965           1985.0
# 975       976           2003.0
# 982       983           1997.0
# 990       991           1997.0
# 997       998           2002.0
#
#                                                  title moviedb_result
# 1                           isle of man tt 2004 review             NA
# 10                      full frame: documentary shorts             NA
# 12   lord of the rings: the return of the king: ext...             NA
# 13                                  nature: antarctica             NA
# 15                                           screamers             NA
# ..                                                 ...            ...
# 964                 metropolitan opera: puccini: tosca             NA
# 975                  tom and jerry: paws for a holiday             NA
# 982                                   wishful thinking             NA
# 990  burn up excess: vol. 2: crimes and missed deme...             NA
# 997                              frida: bonus material             NA
#
# [336 rows x 4 columns]

# %%
test.loc[]
# Out:
# 'lord of the rings: the return of the king: extended edition: bonus material'

# %%
test[test['title']=='gto: great teacher onizuka: set 2']
# Out:
#      movie_id  year_of_release                              title  \
# 134       135           1998.0  gto: great teacher onizuka: set 2
#
#     moviedb_result
# 134             NA

# %% [markdown]
# ### Import Movie Rating File by Users

# %%
# %%time
# Import rating files into dataframe
ls_of_ratings = []

# Specify the pattern matching for glob
rating_files = glob.glob('datasets/training_set/*')

# Loop to get dataframe into list
for filename in rating_files:
    df = pd.read_csv(filename, sep=',', names=['customer_id','rating','date'],skiprows=1)
    df['movie_id'] = int(filename.split('mv_')[1].split('.')[0])
    ls_of_ratings.append(df)

# Concat dataframe together
ratings = pd.concat(ls_of_ratings,ignore_index=True)

print('glob completed')
# Out:
# glob completed
# Wall time: 2min 34s

# %%
print(ratings.shape)
ratings.head()
# Out:
# (100480507, 4)
#    customer_id  rating        date  movie_id
# 0      1488844       3  2005-09-06         1
# 1       822109       5  2005-05-13         1
# 2       885013       4  2005-10-19         1
# 3        30878       4  2005-12-26         1
# 4       823519       3  2004-05-03         1

# %% [markdown]
# ### Merging of Movie title & Rating DataFrame

# %%
ratings_set = set(ratings['movie_id'])
titles_set = set(titles['movie_id'])
print(f" elements present in title df but not in rating df : {titles_set.difference(ratings_set)}")
print(f" elements present in rating df but not in title df : {ratings_set.difference(titles_set)}")
# Out:
#  elements present in title df but not in rating df : set()
#  elements present in rating df but not in title df : set()

# %%
# Merge movie title with rating
df = pd.merge(ratings, titles, on='movie_id', how='inner')
df.shape
# Out:
# (100480507, 6)

# %%
df.head()
# Out:
#    customer_id  rating        date  movie_id  year_of_release            title
# 0      1488844       3  2005-09-06         1           2003.0  Dinosaur Planet
# 1       822109       5  2005-05-13         1           2003.0  Dinosaur Planet
# 2       885013       4  2005-10-19         1           2003.0  Dinosaur Planet
# 3        30878       4  2005-12-26         1           2003.0  Dinosaur Planet
# 4       823519       3  2004-05-03         1           2003.0  Dinosaur Planet

# %%
df.isnull().sum()
# Out:
# customer_id          0
# rating               0
# date                 0
# movie_id             0
# year_of_release    965
# title                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100480507 entries, 0 to 100480506
# Data columns (total 6 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   customer_id      int64
#  1   rating           int64
#  2   date             object
#  3   movie_id         int64
#  4   year_of_release  float64
#  5   title            object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 5.2+ GB

# %%
df['title'].nunique()
# Out:
# 17297

# %%
# Out:
#     customer_id  rating        date  movie_id  year_of_release  \
# 0       1488844       3  2005-09-06         1           2003.0
# 1        822109       5  2005-05-13         1           2003.0
# 2        885013       4  2005-10-19         1           2003.0
# 3         30878       4  2005-12-26         1           2003.0
# 4        823519       3  2004-05-03         1           2003.0
# 5        893988       3  2005-11-17         1           2003.0
# 6        124105       4  2004-08-05         1           2003.0
# 7       1248029       3  2004-04-22         1           2003.0
# 8       1842128       4  2004-05-09         1           2003.0
# 9       2238063       3  2005-05-11         1           2003.0
# 10      1503895       4  2005-05-19         1           2003.0
# 11      2207774       5  2005-06-06         1           2003.0
# 12      2590061       3  2004-08-12         1           2003.0
# 13         2442       3  2004-04-14         1           2003.0
# 14       543865       4  2004-05-28         1           2003.0
# 15      1209119       4  2004-03-23         1           2003.0
# 16       804919       4  2004-06-10         1           2003.0
# 17      1086807       3  2004-12-28         1           2003.0
# 18      1711859       4  2005-05-08         1           2003.0
# 19       372233       5  2005-11-23         1           2003.0
# 20      1080361       3  2005-03-28         1           2003.0
# 21      1245640       3  2005-12-19         1           2003.0
# 22       558634       4  2004-12-14         1           2003.0
# 23      2165002       4  2004-04-06         1           2003.0
# 24      1181550       3  2004-02-01         1           2003.0
# 25      1227322       4  2004-02-06         1           2003.0
# 26       427928       4  2004-02-26         1           2003.0
# 27       814701       5  2005-09-29         1           2003.0
# 28       808731       4  2005-10-31         1           2003.0
# 29       662870       5  2005-08-24         1           2003.0
#
#               title
# 0   Dinosaur Planet
# 1   Dinosaur Planet
# 2   Dinosaur Planet
# 3   Dinosaur Planet
# 4   Dinosaur Planet
# 5   Dinosaur Planet
# 6   Dinosaur Planet
# 7   Dinosaur Planet
# 8   Dinosaur Planet
# 9   Dinosaur Planet
# 10  Dinosaur Planet
# 11  Dinosaur Planet
# 12  Dinosaur Planet
# 13  Dinosaur Planet
# 14  Dinosaur Planet
# 15  Dinosaur Planet
# 16  Dinosaur Planet
# 17  Dinosaur Planet
# 18  Dinosaur Planet
# 19  Dinosaur Planet
# 20  Dinosaur Planet
# 21  Dinosaur Planet
# 22  Dinosaur Planet
# 23  Dinosaur Planet
# 24  Dinosaur Planet
# 25  Dinosaur Planet
# 26  Dinosaur Planet
# 27  Dinosaur Planet
# 28  Dinosaur Planet
# 29  Dinosaur Planet
